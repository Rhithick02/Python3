# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age, df.bought_insurance, marker = '+', color = 'red')
plt.show()

# %%
X_train = df[:24]['age']
Y_train = df[:24]['bought_insurance']

# %%
X_test = df[24:]['age']
Y_test = df[24:]['bought_insurance']

# %%
def element_sigmoid(theta, x):
    temp = theta[0]
    temp += theta[1] * x
    den = 1 + math.exp(-temp)
    return 1 / den

# %%
def cost_fn(X, Y, theta):
    temp = 0
    for i in range(len(X)):
        try:
            temp += Y[i] * math.log(element_sigmoid(theta, X[i])) + (1 - Y[i]) * math.log(1-element_sigmoid(theta, X[i]))
        except:
            return float('inf')
    temp *= (-1/m)
    return temp

# %%
alpha = 0.0001
no_of_iterations = 5000
theta = [1, 1]
m = len(X_train)
n = len(theta)

# %%
for i in range(no_of_iterations):
    error = [0] * n
    for j in range(m):
        error[0] += (element_sigmoid(theta, X_train[j]) - Y_train[j])
        error[1] += (element_sigmoid(theta, X_train[j]) - Y_train[j]) * X_train[j]
    error[0] *= alpha / m
    error[1] *= alpha / m
    theta[0] = theta[0] - error[0]
    theta[1] = theta[1] - error[1]
    print(cost_fn(X_train, Y_train, theta))
# Out:
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# ...

# %%
theta[0], theta[1]
# Out:
# (0.8999658590629828, -0.007119695405983247)

# %%
x = np.arange(0, 100, 0.1)
y = theta[0] + theta[1] * x

# %%
plt.plot(x, y)
plt.scatter(df.age, df.bought_insurance, marker = '+', color = 'red')
plt.show()

# %%
X_test
# Out:
# 24    50
# 25    54
# 26    23
# Name: age, dtype: int64

# %%
element_sigmoid(theta, X_test[26])
# Out:
# 0.6761671595346807

# %%
Y_test
# Out:
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64
