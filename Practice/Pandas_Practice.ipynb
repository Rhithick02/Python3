# %%
import pandas as pd

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
temp = df[['total_sqft', 'balcony', 'price']][df['total_sqft'] == df['total_sqft'].min()]
temp
# Out:
#      total_sqft  balcony  price
# 4086          1      NaN  120.0

# %%
col = df.columns
col
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
col = list(col)
new_col = col[1:2] + col[0:1] + col[2:]
new_col
# Out:
# ['availability',
#  'area_type',
#  'location',
#  'size',
#  'society',
#  'total_sqft',
#  'bath',
#  'balcony',
#  'price']

# %%
temp = df
temp.columns = new_col

# %%
temp
# Out:
#                availability      area_type                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.set_index('size', inplace = True)
df.loc['2 BHK']
# Out:
#                availability      area_type                  location  society  \
# size
# 2 BHK  Super built-up  Area         19-Dec  Electronic City Phase II  Coomee
# 2 BHK  Super built-up  Area  Ready To Move                  Kothanur      NaN
# 2 BHK  Super built-up  Area  Ready To Move                Whitefield  DuenaTa
# 2 BHK  Super built-up  Area  Ready To Move        7th Phase JP Nagar  Shncyes
# 2 BHK        Built-up  Area  Ready To Move                 Gottigere      NaN
# ...                     ...            ...                       ...      ...
# 2 BHK  Super built-up  Area  Ready To Move      Annaiah Reddy Layout      NaN
# 2 BHK  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar  GrrvaGr
# 2 BHK  Super built-up  Area  Ready To Move              Rachenahalli      NaN
# 2 BHK  Super built-up  Area  Ready To Move                 Bellandur      NaN
# 2 BHK        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  Mahla T
#
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#             size          availability      area_type  \
# 0          2 BHK  Super built-up  Area         19-Dec
# 1      4 Bedroom            Plot  Area  Ready To Move
# 2          3 BHK        Built-up  Area  Ready To Move
# 3          3 BHK  Super built-up  Area  Ready To Move
# 4          2 BHK  Super built-up  Area  Ready To Move
# ...          ...                   ...            ...
# 13315  5 Bedroom        Built-up  Area  Ready To Move
# 13316      4 BHK  Super built-up  Area  Ready To Move
# 13317      2 BHK        Built-up  Area  Ready To Move
# 13318      4 BHK  Super built-up  Area         18-Jun
# 13319      1 BHK  Super built-up  Area  Ready To Move
#
#                        location  society total_sqft  bath  balcony   price
# 0      Electronic City Phase II  Coomee        1056   2.0      1.0   39.07
# 1              Chikka Tirupathi  Theanmp       2600   5.0      3.0  120.00
# 2                   Uttarahalli      NaN       1440   2.0      3.0   62.00
# ...

# %%
temp = df.fillna(0)
temp
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...
